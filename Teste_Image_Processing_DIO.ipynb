# %%
from img_processing_project_dio.processing import combination, transformation
from img_processing_project_dio.utils import io, plot

# %%
image_1 = io.read_image("C:\workspace_git\image_processing_th\image_1.jpg")
image_2 = io.read_image("C:\workspace_git\image_processing_th\image_2.jpg")

# %%
plot.plot_image(image_1)
plot.plot_image(image_2)

# %%
image_result = combination.transfer_histogram(image_1,image_2)
# Out:
# C:\workspace_git\image_processing_th\img_processing_project_dio\processing\combination.py:17: FutureWarning: `multichannel` is a deprecated argument name for `match_histograms`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   matched_image = match_histograms(image_1, image_2, multichannel=True)

# %%
plot.plot_result(image_1,image_2,image_result)
